# %%
import sys
import parse_PAGE
import cv2
import line_extraction
import numpy as np
import os
import traceback
from collections import defaultdict
from scipy import ndimage
import json
import codecs
from svgpathtools import Path, Line
from scipy.interpolate import griddata
import pandas as pd


import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
def generate_offset_mapping(img, ts, path, offset_1, offset_2, max_min = None, cube_size = None):
    # cube_size = 80

    offset_1_pts = []
    offset_2_pts = []
    # for t in ts:
    for i in range(len(ts)):
        t = ts[i]
        pt = path.point(t)

        norm = None
        if i == 0:
            norm = normal(pt, path.point(ts[i+1]))
            norm = norm / dis(complex(0,0), norm)
        elif i == len(ts)-1:
            norm = normal(path.point(ts[i-1]), pt)
            norm = norm / dis(complex(0,0), norm)
        else:
            norm1 = normal(path.point(ts[i-1]), pt)
            norm1 = norm1 / dis(complex(0,0), norm1)
            norm2 = normal(pt, path.point(ts[i+1]))
            norm2 = norm2 / dis(complex(0,0), norm2)

            norm = (norm1 + norm2)/2
            norm = norm / dis(complex(0,0), norm)

        offset_vector1 = offset_1 * norm
        offset_vector2 = offset_2 * norm

        pt1 = pt + offset_vector1
        pt2 = pt + offset_vector2

        offset_1_pts.append(complexToNpPt(pt1))
        offset_2_pts.append(complexToNpPt(pt2))

    offset_1_pts = np.array(offset_1_pts)
    offset_2_pts = np.array(offset_2_pts)

    h,w = img.shape[:2]

    offset_source2 = np.array([(cube_size*i, 0) for i in range(len(offset_1_pts))], dtype=np.float32)
    offset_source1 = np.array([(cube_size*i, cube_size) for i in range(len(offset_2_pts))], dtype=np.float32)

    offset_source1 = offset_source1[::-1]
    offset_source2 = offset_source2[::-1]

    source = np.concatenate([offset_source1, offset_source2])
    destination = np.concatenate([offset_1_pts, offset_2_pts])

    source = source[:,::-1]
    destination = destination[:,::-1]

    n_w = int(offset_source2[:,0].max())
    n_h = int(cube_size)

    grid_x, grid_y = np.mgrid[0:n_h, 0:n_w]

    grid_z = griddata(source, destination, (grid_x, grid_y), method='cubic')
    map_x = np.append([], [ar[:,1] for ar in grid_z]).reshape(n_h,n_w)
    map_y = np.append([], [ar[:,0] for ar in grid_z]).reshape(n_h,n_w)
    map_x_32 = map_x.astype('float32')
    map_y_32 = map_y.astype('float32')

    rectified_to_warped_x = map_x_32
    rectified_to_warped_y = map_y_32

    grid_x, grid_y = np.mgrid[0:h, 0:w]
    grid_z = griddata(source, destination, (grid_x, grid_y), method='cubic')
    map_x = np.append([], [ar[:,1] for ar in grid_z]).reshape(h,w)
    map_y = np.append([], [ar[:,0] for ar in grid_z]).reshape(h,w)
    map_x_32 = map_x.astype('float32')
    map_y_32 = map_y.astype('float32')

    warped_to_rectified_x = map_x_32
    warped_to_rectified_y = map_y_32

    return rectified_to_warped_x, rectified_to_warped_y, warped_to_rectified_x, warped_to_rectified_y, max_min


def dis(pt1, pt2):
    a = (pt1.real - pt2.real)**2
    b = (pt1.imag - pt2.imag)**2
    return np.sqrt(a+b)

def complexToNpPt(pt):
    return np.array([pt.real, pt.imag], dtype=np.float32)

def normal(pt1, pt2):
    dif = pt1 - pt2
    return complex(-dif.imag, dif.real)

def find_t_spacing(path, cube_size):

    l = path.length()
    error = 0.01
    init_step_size = cube_size / l

    last_t = 0
    cur_t = 0
    pts = []
    ts = [0]
    pts.append(complexToNpPt(path.point(cur_t)))
    path_lookup = {}
    for target in np.arange(cube_size, int(l), cube_size):
        step_size = init_step_size
        for i in range(1000):
            cur_length = dis(path.point(last_t), path.point(cur_t))
            if np.abs(cur_length - cube_size) < error:
                break

            step_t = min(cur_t + step_size, 1.0)
            step_l = dis(path.point(last_t), path.point(step_t))

            if np.abs(step_l - cube_size) < np.abs(cur_length - cube_size):
                cur_t = step_t
                continue

            step_t = max(cur_t - step_size, 0.0)
            step_t = max(step_t, last_t)
            step_t = max(step_t, 1.0)

            step_l = dis(path.point(last_t), path.point(step_t))

            if np.abs(step_l - cube_size) < np.abs(cur_length - cube_size):
                cur_t = step_t
                continue

            step_size = step_size / 2.0

        last_t = cur_t

        ts.append(cur_t)
        pts.append(complexToNpPt(path.point(cur_t)))

    pts = np.array(pts)

    return ts


def find_best_xml(list_of_files, filename):

    if len(list_of_files) <= 1:
        return list_of_files

    print("Selecting multiple options from:")

    line_cnts = []
    for xml_path in list_of_files:
        test_xml_path = os.path.join(xml_path, filename+".xml")
        print(test_xml_path)
        with open(test_xml_path) as f:
            num_lines = sum(1 for line in f.readlines() if len(line.strip())>0)
        line_cnts.append((num_lines, xml_path))
    line_cnts.sort(key=lambda x:x[0], reverse=True)
    print("Sorted by line count...")
    ret = [l[1] for l in line_cnts]
    return ret

# %%
def get_basename(img_name):
    head, tail = os.path.split(img_name)
    basename = 'base_' + tail
    basename = basename[:-4]
    return basename

def handle_single_para(para_df, output_directory):
    
    output_data = []
    num_lines = len(para_df)
    print('....', num_lines)
    if os.path.exists(para_df.image_file.iloc[0]):
        img = cv2.imread(para_df.image_file.iloc[0])
    else:
        print('....File not found', para_df.image_file.iloc[0])
        return ''
    basename = get_basename(para_df.image_file.iloc[0])    
    
    all_lines = ""
    
    # get rid of png/jpg extension
    
    for region in [0]:
        region_output_data = []
        #print('in region', region)
        for ind, line in enumerate(para_df.line_number):
            if len(para_df.polygon_pts[ind]) == 0:
                print('No polygon pts in img', para_df.image_file.iloc[0][-15:],
                      'line number', line)
                continue
            #print('....ind, line', ind, line)
            line_mask = line_extraction.extract_region_mask(img, para_df.polygon_pts[ind])
            masked_img = img.copy()
            masked_img[line_mask==0] = 0

            summed_axis0 = (masked_img.astype(float) / 255).sum(axis=0)
            summed_axis1 = (masked_img.astype(float) / 255).sum(axis=1)

            non_zero_cnt0 = np.count_nonzero(summed_axis0) / float(len(summed_axis0))
            non_zero_cnt1 = np.count_nonzero(summed_axis1) / float(len(summed_axis1))

            avg_height0 = np.median(summed_axis0[summed_axis0 != 0])
            avg_height1 = np.median(summed_axis1[summed_axis1 != 0])

            avg_height = min(avg_height0, avg_height1)
            if non_zero_cnt0 > non_zero_cnt1:
                target_step_size = avg_height0
            else:
                target_step_size = avg_height1

            paths = []
            for i in range(len(para_df.baseline[ind])-1):
                i_1 = i+1

                p1 = para_df.baseline[ind][i]
                p2 = para_df.baseline[ind][i_1]

                p1_c = complex(*p1)
                p2_c = complex(*p2)


                paths.append(Line(p1_c, p2_c))


            # Add a bit on the end
            tan = paths[-1].unit_tangent(1.0)
            p3_c = p2_c + target_step_size * tan
            paths.append(Line(p2_c, p3_c))

            path = Path(*paths)

            ts = find_t_spacing(path, target_step_size)
            

            #Changing this causes issues in pretraining - not sure why
            target_height = 32

            rectified_to_warped_x, rectified_to_warped_y, warped_to_rectified_x, warped_to_rectified_y, max_min = generate_offset_mapping(masked_img, ts, path, 0, -2*target_step_size, cube_size = target_height)
            warped_above = cv2.remap(line_mask, rectified_to_warped_x, rectified_to_warped_y, cv2.INTER_CUBIC, borderValue=(0,0,0))

            rectified_to_warped_x, rectified_to_warped_y, warped_to_rectified_x, warped_to_rectified_y, max_min = generate_offset_mapping(masked_img, ts, path, 2*target_step_size, 0, cube_size = target_height)
            warped_below = cv2.remap(line_mask, rectified_to_warped_x, rectified_to_warped_y, cv2.INTER_CUBIC, borderValue=(0,0,0))

            above_scale =  np.max((warped_above.astype(float) / 255).sum(axis=0))
            below_scale = np.max((warped_below.astype(float) / 255).sum(axis=0))

            ab_sum = above_scale + below_scale
            above = target_step_size * (above_scale/ab_sum)
            below = target_step_size * (below_scale/ab_sum)

            above = target_step_size * (above_scale/(target_height/2.0))
            below = target_step_size * (below_scale/(target_height/2.0))
            target_step_size = above + below
            ts = find_t_spacing(path, target_step_size)
            if len(ts) <= 1:
                print('Not doing line', line)
                continue
            rectified_to_warped_x, rectified_to_warped_y, warped_to_rectified_x, warped_to_rectified_y, max_min = generate_offset_mapping(masked_img, ts, path, below, -above, cube_size=target_height)

            ####MEHREEN COMMENT to prevent image from flipping
            #rectified_to_warped_x = rectified_to_warped_x[::-1,::-1]
            #rectified_to_warped_y = rectified_to_warped_y[::-1,::-1]
            ###END MEHREEN COMMENT
            warped_to_rectified_x = warped_to_rectified_x[::-1,::-1]
            warped_to_rectified_y = warped_to_rectified_y[::-1,::-1]

            warped = cv2.remap(img, rectified_to_warped_x, rectified_to_warped_y, cv2.INTER_CUBIC, borderValue=(255,255,255))

            ####MEHREEN ADD
            # Want to prevent image warping but we want coordinates to be warped
            rectified_to_warped_x = rectified_to_warped_x[::-1,::-1]
            rectified_to_warped_y = rectified_to_warped_y[::-1,::-1]

            #### END MEHREEN ADD
            
            
            mapping = np.stack([rectified_to_warped_y, rectified_to_warped_x], axis=2)

            top_left = mapping[0,0,:] / np.array(img.shape[:2]).astype(np.float32)
            btm_right = mapping[min(mapping.shape[0]-1, target_height-1), min(mapping.shape[1]-1, target_height-1),:] / np.array(img.shape[:2]).astype(np.float32)


            line_points = []
            for i in range(0,mapping.shape[1],target_height):

                x0 = float(rectified_to_warped_x[0,i])
                x1 = float(rectified_to_warped_x[-1,i])

                y0 = float(rectified_to_warped_y[0,i])
                y1 = float(rectified_to_warped_y[-1,i])

                line_points.append({
                    "x0": x0, #MEhreen change x0,
                    "x1": x1, #Mehreen change x1,
                    "y0": y1, #Mehreen change from y0,
                    "y1": y0, #Mehreen change from y1
                })
                
                
                                
            ###Mehreen add for viewing

#            plt.imshow(img) # or display line warped
#            print("****", line_points)
#            for coord in line_points:
#                x = coord["x0"]
#                y = coord["y0"]
#                x1 = coord["x1"]
#                y1 = coord["y1"]
                #rect = patches.Rectangle((x, y), np.abs(x-coord[2]), np.abs(y-coord[3]), facecolor='green')
#                rect = patches.Rectangle((x, y), 10, 10, facecolor='blue')
#                rect1 = patches.Rectangle((x1, y1), 10, 10, facecolor='red')
#                plt.gca().add_patch(rect)  
#                plt.gca().add_patch(rect1)
#            rect0 = patches.Rectangle((line_points[0]["x0"], line_points[0]["y0"]), 10, 10, facecolor='yellow') 
#            plt.gca().add_patch(rect0)
#            plt.show()
             ## ENd mehreen add for view   
                
            
            output_file = os.path.join(output_directory, 
                          basename, "{}~{}~{}.png".format(basename, region, line))
            warp_output_file = os.path.join(output_directory, basename, "{}-{}.png".format(basename, line))
            warp_output_file_save = os.path.join(basename, "{}-{}.png".format(basename, str(len(region_output_data))))
            save_file = os.path.join(basename, "{}~{}~{}.png".format(basename, region, line))
            region_output_data.append({
                "gt": para_df.ground_truth[ind],
                "image_path": save_file,
                "sol": line_points[0],
                "lf": line_points,
                "hw_path": warp_output_file #MEhreen commentwarp_output_file_save
            })
            #print('****', output_file)
            if not os.path.exists(os.path.dirname(output_file)):
                try:
                    os.makedirs(os.path.dirname(output_file))
                except OSError as exc:
                    raise Exception("Could not write file")

            cv2.imwrite(warp_output_file, warped)

        output_data.extend(region_output_data)

    
    if len(region_output_data) == 0:
        return ''
        
    output_data_path =os.path.join(output_directory, basename, "{}.json".format(basename))
    if not os.path.exists(os.path.dirname(output_data_path)):
        os.makedirs(os.path.dirname(output_data_path))

    with open(output_data_path, 'w') as f:
        json.dump(output_data, f)

    return output_data_path

# %%
def convert_str_to_int_tuples(df_col):
    tmp_col = []
    for ind, item in enumerate(df_col):
        if not pd.isna(item):
            item = eval(item)    
            tmp_col.append([(round(x[0]), round(x[1])) for x in item])
        else:
            tmp_col.append([])
    return tmp_col

def rotate_polygon(p):
    if len(p) == 8 or len(p) == 7:
        poly = p[4:]
        poly.extend(p[0:4])
        return poly
    if len(p) == 4:
        poly = [p[2], p[3], p[0], p[1]]
        return poly
    else:
        print("something wrong", p)
        return []
    
def rotate_poly_list(df_col):
    poly_list = [rotate_polygon(p) for p in df_col]
    return poly_list


def rotate_baseline_list(df_col):
    b_list = [b[::-1] for b in df_col]
    return b_list

# %%
def process_arabic_dir(out_path, set_name, region_types):
    
    df = pd.read_csv(os.path.join(out_path, set_name+'.csv'))
    df.baseline = convert_str_to_int_tuples(df.baseline)
    #df.baseline = rotate_baseline_list(df.baseline)
    df.polygon_pts = convert_str_to_int_tuples(df.polygon_pts)
    #df.polygon_pts = rotate_poly_list(df.polygon_pts) 
    
    files = df.image_file
    print(f'Total files in set {set_name}: {len(set(files))}')
    
    all_ground_truth = []
    for para_numb in set(df.paragraph_number):
        para_df = df[df.paragraph_number == para_numb]
        para_df.reset_index(inplace=True)
        valid_region = any(s in para_df['region_type'][0] for s in region_types)
        if not valid_region:
            continue
        para_df = para_df.copy()
        para_df = para_df.reset_index(drop=True)
        head, tail = os.path.split(para_df.image_file.iloc[0])
        basename = 'base_' + tail
        basename = basename[:-4]
        img_path = para_df.image_file.iloc[0]
        
        json_path = handle_single_para(para_df, out_path+set_name)  
            
        # para not added    
        if len(json_path) == 0:
            continue
            
        all_ground_truth.append([json_path, img_path])
        if len(all_ground_truth)%100 == 0:
            print('done', len(all_ground_truth))
        
    return all_ground_truth

def process_notdone_arabic_dir(out_path, set_name, region_types):
    
    df = pd.read_csv(os.path.join(out_path, set_name+'.csv'))
    df.baseline = convert_str_to_int_tuples(df.baseline)
    #df.baseline = rotate_baseline_list(df.baseline)
    df.polygon_pts = convert_str_to_int_tuples(df.polygon_pts)
    #df.polygon_pts = rotate_poly_list(df.polygon_pts) 
    
    files = df.image_file
    print(f'Total files in set {set_name}: {len(set(files))}')
    
    all_ground_truth = []
    for para_numb in set(df.paragraph_number):
        para_df = df[df.paragraph_number == para_numb]
        para_df = para_df.copy()
        para_df = para_df.reset_index(drop=True)

        valid_region = False
        if not pd.isna(para_df['region_type'][0]):
            valid_region = any(s in para_df['region_type'][0] for s in region_types)
        if not valid_region:
            continue
        
        img_path = para_df.image_file.iloc[0]
        basename = get_basename(img_path)
        
        tmp_path = os.path.join(out_path, set_name, basename, basename + '.json')
        
        #print('...', tmp_path)
        if os.path.isfile(tmp_path):
            json_path = tmp_path
            print('... Done', basename)
        else: 
            print('....Doing', basename)
            json_path = handle_single_para(para_df, out_path+set_name)  
            
        # para not added    
        if len(json_path) == 0:
            print('Not added', basename)
            continue
            
        all_ground_truth.append([json_path, img_path])
        if len(all_ground_truth)%100 == 0:
            print('done', len(all_ground_truth))
        
    return all_ground_truth
    
    
def process_notdone_arabic_dir_ver2(csv_file, out_path, set_name, region_types):
    
    df = pd.read_csv(csv_file)
    df.baseline = convert_str_to_int_tuples(df.baseline)
    #df.baseline = rotate_baseline_list(df.baseline)
    df.polygon_pts = convert_str_to_int_tuples(df.polygon_pts)
    #df.polygon_pts = rotate_poly_list(df.polygon_pts) 
    
    files = df.image_file
    print(f'Total files in set {set_name}: {len(set(files))}')
    
    all_ground_truth = []
    for para_numb in set(df.paragraph_number):
        para_df = df[df.paragraph_number == para_numb]
        para_df = para_df.copy()
        para_df = para_df.reset_index(drop=True)

        valid_region = False
        if not pd.isna(para_df['region_type'][0]):
            valid_region = any(s in para_df['region_type'][0] for s in region_types)
        if not valid_region:
            continue
        
        img_path = para_df.image_file.iloc[0]
        basename = get_basename(img_path)
        
        tmp_path = os.path.join(out_path, set_name, basename, basename + '.json')
        
        #print('...', tmp_path)
        if os.path.isfile(tmp_path):
            json_path = tmp_path
            print('... Done', basename)
        else: 
            print('....Doing', basename)
            json_path = handle_single_para(para_df, out_path+set_name)  
            
        # para not added    
        if len(json_path) == 0:
            print('Not added', basename)
            continue
            
        all_ground_truth.append([json_path, img_path])
        if len(all_ground_truth)%100 == 0:
            print('done', len(all_ground_truth))
        
    return all_ground_truth
        
    
# This one expects input and output paths to be the same
def main_arabic_preprocess():
    
    # Make sure there is a / at end of path
    paths = ['/home/msaeed3/mehreen/datasets/RASAM/regions_sfr/',
             '/home/msaeed3/mehreen/datasets/RASM/regions_sfr/',
             '/home/msaeed3/mehreen/datasets/MoiseK/', 
             '/home/msaeed3/mehreen/datasets/KHATT/ParagraphImages_v1.0/UniqueTextParagraphs/']
    ajsfljsdf
    salfjsdlkfjs# Make sure all names are correct
    set_name = ['Train', 'Valid']
    khatt_sets = ['Train', 'Validate']
    all_train = []
    all_valid = []
    
    for path in paths:
        set_to_use = set_name
        if 'KHATT' in path:
            set_to_use = khatt_sets
        train_gt = process_notdone_arabic_dir(path, set_to_use[0], ['paragraph', 'text'])
        valid_gt = process_notdone_arabic_dir(path, set_to_use[1], ['paragraph', 'text'])

        all_train.extend(train_gt)
        all_valid.extend(valid_gt)

    path = '/home/msaeed3/mehreen/datasets/arabic_all/'     
    train_json = os.path.join(path, set_name[0]+'.json')
    valid_json = os.path.join(path, set_name[1]+'.json')
    with open(train_json, 'w') as f:
        json.dump(all_train, f)

    with open(valid_json, 'w') as f:
        json.dump(all_valid, f)    
        
#main_arabic_preprocess()
#print('Preprocessing done!')

# %%
# This one assumes that all the lowest level json files are made
# now the only thing to do is to create the higher level json files with links to lower level files

def create_higher_level_json():
    
    all_train = []
    all_valid = []
    # Make sure there is a / at end of path
    input_paths = ['/home/msaeed3/mehreen/datasets/RASAM/regions_sfr/',
             '/home/msaeed3/mehreen/datasets/RASM/regions_sfr/', 
             '/home/msaeed3/mehreen/datasets/KHATT/ParagraphImages_v1.0/UniqueTextParagraphs/',
             '/home/msaeed3/mehreen/datasets/MoiseK/datasets/', 
             '/home/msaeed3/mehreen/datasets/MoiseK/datasets/']    
    
    # RASAM, RASM, KHATT
    set_name = [['Train', 'Valid'], ['Train', 'Valid'], ['Train', 'Validate'], 
                # MoiseK
                ['Train_01', 'Valid_01'], ['Train_02', 'Valid_02']]

    
    base_files_dir = [['Train', 'Valid'], ['Train', 'Valid'], ['Train', 'Validate'], 
                # MoiseK
                ['all_files', 'all_files'], ['all_files_02', 'all_files_02']]

      
    for path, set_to_use, base_dir in zip(input_paths, set_name, base_files_dir):
        train_csv = os.path.join(path, set_to_use[0]+'.csv')
        valid_csv = os.path.join(path, set_to_use[1]+'.csv')
        train_gt = process_notdone_arabic_dir_ver2(train_csv, path, base_dir[0], ['paragraph', 'text'])
        valid_gt = process_notdone_arabic_dir_ver2(valid_csv, path, base_dir[1], ['paragraph', 'text'])

        all_train.extend(train_gt)
        all_valid.extend(valid_gt)

    print('all_valid....', all_valid)    
    out_path = '/home/msaeed3/mehreen/datasets/arabic_all/'     
    train_json = os.path.join(out_path, 'Train_rrk12' + '.json')
    valid_json = os.path.join(out_path, 'Valid_rrk12' + '.json')
    with open(train_json, 'w') as f:
        json.dump(all_train, f)

    with open(valid_json, 'w') as f:
        json.dump(all_valid, f)        
    
create_higher_level_json()    
print("all files done")
# Out:
# Total files in set Train: 349
# ... Done base_BULAC_MS_ARA_609_00059_0
# ... Done base_BULAC_MS_ARA_1977_0074_0
# ... Done base_BULAC_MS_ARA_1977_0039_0
# ... Done base_BULAC_MS_ARA_609_00086_0
# ... Done base_BULAC_MS_ARA_609_00078_0
# ... Done base_BULAC_MS_ARA_1977_0022_0
# ... Done base_BULAC_MS_ARA_417_0051_0
# ... Done base_BULAC_MS_ARA_417_0078_0
# ... Done base_BULAC_MS_ARA_1977_0053_0
# ... Done base_BULAC_MS_ARA_609_00184_0
# ... Done base_BULAC_MS_ARA_609_00080_0
# ... Done base_BULAC_MS_ARA_1977_0075_0
# ... Done base_BULAC_MS_ARA_1977_0058_0
# ... Done base_BULAC_MS_ARA_1977_0123_0
# ... Done base_BULAC_MS_ARA_609_00105_1
# ... Done base_BULAC_MS_ARA_609_00115_0
# ... Done base_BULAC_MS_ARA_1977_0030_0
# ... Done base_BULAC_MS_ARA_609_00073_0
# ... Done base_BULAC_MS_ARA_609_00089_0
# ... Done base_BULAC_MS_ARA_1977_0127_0
# ... Done base_BULAC_MS_ARA_609_00004_0
# ... Done base_BULAC_MS_ARA_417_0044_0
# ... Done base_BULAC_MS_ARA_417_0080_0
# ... Done base_BULAC_MS_ARA_1977_0124_0
# ... Done base_BULAC_MS_ARA_1977_0052_0
# ... Done base_BULAC_MS_ARA_417_0093_0
# ... Done base_BULAC_MS_ARA_609_00159_0
# ... Done base_BULAC_MS_ARA_609_00175_0
# ... Done base_BULAC_MS_ARA_1977_0198_0
# ... Done base_BULAC_MS_ARA_1977_0013_0
# ... Done base_BULAC_MS_ARA_1977_0031_0
# ... Done base_BULAC_MS_ARA_1977_0020_0
# ... Done base_BULAC_MS_ARA_417_0082_0
# ... Done base_BULAC_MS_ARA_417_0018_0
# ... Done base_BULAC_MS_ARA_609_00088_0
# ... Done base_BULAC_MS_ARA_609_00110_0
# ... Done base_BULAC_MS_ARA_417_0020_0
# ... Done base_BULAC_MS_ARA_417_0004_0
# ... Done base_BULAC_MS_ARA_609_00045_0
# ... Done base_BULAC_MS_ARA_609_00178_0
# ... Done base_BULAC_MS_ARA_417_0033_0
# ... Done base_BULAC_MS_ARA_609_00174_0
# ... Done base_BULAC_MS_ARA_609_00012_0
# ... Done base_BULAC_MS_ARA_609_00044_0
# ... Done base_BULAC_MS_ARA_417_0014_0
# ... Done base_BULAC_MS_ARA_1977_0034_0
# ... Done base_BULAC_MS_ARA_609_00199_0
# ... Done base_BULAC_MS_ARA_417_0049_0
# ... Done base_BULAC_MS_ARA_609_00005_0
# ... Done base_BULAC_MS_ARA_1977_0128_0
# ... Done base_BULAC_MS_ARA_609_00043_0
# ... Done base_BULAC_MS_ARA_609_00053_0
# ... Done base_BULAC_MS_ARA_417_0065_0
# ... Done base_BULAC_MS_ARA_609_00122_0
# ... Done base_BULAC_MS_ARA_417_0040_0
# ... Done base_BULAC_MS_ARA_417_0039_0
# ... Done base_BULAC_MS_ARA_609_00019_0
# ... Done base_BULAC_MS_ARA_417_0077_0
# ... Done base_BULAC_MS_ARA_1977_0099_0
# ... Done base_BULAC_MS_ARA_1977_0046_0
# ... Done base_BULAC_MS_ARA_1977_0146_0
# ... Done base_BULAC_MS_ARA_609_00035_0
# ... Done base_BULAC_MS_ARA_1977_0120_0
# ... Done base_BULAC_MS_ARA_417_0075_0
# ... Done base_BULAC_MS_ARA_417_0029_0
# ... Done base_BULAC_MS_ARA_609_00136_0
# ... Done base_BULAC_MS_ARA_417_0037_0
# ... Done base_BULAC_MS_ARA_417_0022_0
# ... Done base_BULAC_MS_ARA_609_00114_0
# ... Done base_BULAC_MS_ARA_417_0072_0
# ... Done base_BULAC_MS_ARA_1977_0038_0
# ... Done base_BULAC_MS_ARA_609_00049_1
# ... Done base_BULAC_MS_ARA_609_00022_0
# ... Done base_BULAC_MS_ARA_417_0081_0
# ... Done base_BULAC_MS_ARA_1977_0190_0
# ... Done base_BULAC_MS_ARA_609_00057_1
# ... Done base_BULAC_MS_ARA_609_00147_0
# ... Done base_BULAC_MS_ARA_1977_0141_0
# ... Done base_BULAC_MS_ARA_1977_0162_0
# ... Done base_BULAC_MS_ARA_609_00021_0
# ... Done base_BULAC_MS_ARA_609_00126_0
# ... Done base_BULAC_MS_ARA_1977_0108_0
# ... Done base_BULAC_MS_ARA_1977_0081_0
# ... Done base_BULAC_MS_ARA_417_0090_0
# ... Done base_BULAC_MS_ARA_609_00082_0
# ... Done base_BULAC_MS_ARA_609_00179_0
# ... Done base_BULAC_MS_ARA_609_00168_0
# ... Done base_BULAC_MS_ARA_417_0064_0
# ... Done base_BULAC_MS_ARA_1977_0178_0
# ... Done base_BULAC_MS_ARA_417_0085_0
# ... Done base_BULAC_MS_ARA_417_0088_0
# ... Done base_BULAC_MS_ARA_1977_0131_1
# ... Done base_BULAC_MS_ARA_1977_0028_0
# ... Done base_BULAC_MS_ARA_417_0076_0
# ... Done base_BULAC_MS_ARA_609_00085_0
# ... Done base_BULAC_MS_ARA_609_00155_0
# ... Done base_BULAC_MS_ARA_417_0036_0
# ... Done base_BULAC_MS_ARA_1977_0029_0
# ... Done base_BULAC_MS_ARA_1977_0093_1
# ... Done base_BULAC_MS_ARA_609_00032_0
# done 100
# ... Done base_BULAC_MS_ARA_417_0021_0
# ... Done base_BULAC_MS_ARA_1977_0056_0
# ... Done base_BULAC_MS_ARA_417_0059_0
# ... Done base_BULAC_MS_ARA_1977_0066_0
# ... Done base_BULAC_MS_ARA_609_00177_0
# ... Done base_BULAC_MS_ARA_609_00099_0
# ... Done base_BULAC_MS_ARA_609_00152_0
# ... Done base_BULAC_MS_ARA_609_00025_0
# ... Done base_BULAC_MS_ARA_1977_0185_0
# ... Done base_BULAC_MS_ARA_417_0030_0
# ... Done base_BULAC_MS_ARA_1977_0071_0
# ... Done base_BULAC_MS_ARA_417_0045_0
# ... Done base_BULAC_MS_ARA_1977_0173_0
# ... Done base_BULAC_MS_ARA_1977_0142_0
# ... Done base_BULAC_MS_ARA_1977_0174_0
# ... Done base_BULAC_MS_ARA_417_0043_0
# ... Done base_BULAC_MS_ARA_1977_0168_0
# ... Done base_BULAC_MS_ARA_1977_0117_0
# ... Done base_BULAC_MS_ARA_609_00038_0
# ... Done base_BULAC_MS_ARA_417_0062_0
# ... Done base_BULAC_MS_ARA_1977_0085_0
# ... Done base_BULAC_MS_ARA_417_0009_0
# ... Done base_BULAC_MS_ARA_609_00106_0
# ... Done base_BULAC_MS_ARA_1977_0015_0
# ... Done base_BULAC_MS_ARA_417_0091_0
# ... Done base_BULAC_MS_ARA_417_0061_0
# ... Done base_BULAC_MS_ARA_1977_0172_0
# ... Done base_BULAC_MS_ARA_1977_0069_0
# ... Done base_BULAC_MS_ARA_417_0016_0
# ... Done base_BULAC_MS_ARA_1977_0063_0
# ... Done base_BULAC_MS_ARA_1977_0072_0
# ... Done base_BULAC_MS_ARA_1977_0139_0
# ... Done base_BULAC_MS_ARA_417_0042_0
# ... Done base_BULAC_MS_ARA_417_0046_0
# ... Done base_BULAC_MS_ARA_1977_0100_0
# ... Done base_BULAC_MS_ARA_417_0047_0
# ... Done base_BULAC_MS_ARA_609_00166_0
# ... Done base_BULAC_MS_ARA_1977_0153_0
# ... Done base_BULAC_MS_ARA_1977_0021_0
# ... Done base_BULAC_MS_ARA_417_0079_0
# ... Done base_BULAC_MS_ARA_1977_0087_0
# ... Done base_BULAC_MS_ARA_1977_0118_0
# ... Done base_BULAC_MS_ARA_1977_0033_0
# ... Done base_BULAC_MS_ARA_609_00203_0
# ... Done base_BULAC_MS_ARA_417_0031_0
# ... Done base_BULAC_MS_ARA_417_0050_0
# ... Done base_BULAC_MS_ARA_417_0057_0
# ... Done base_BULAC_MS_ARA_417_0069_0
# ... Done base_BULAC_MS_ARA_1977_0119_0
# ... Done base_BULAC_MS_ARA_417_0086_0
# ... Done base_BULAC_MS_ARA_609_00156_0
# ... Done base_BULAC_MS_ARA_1977_0137_0
# ... Done base_BULAC_MS_ARA_1977_0152_0
# ... Done base_BULAC_MS_ARA_417_0066_0
# ... Done base_BULAC_MS_ARA_1977_0155_0
# ... Done base_BULAC_MS_ARA_609_00042_0
# ... Done base_BULAC_MS_ARA_417_0056_0
# ... Done base_BULAC_MS_ARA_1977_0170_0
# ... Done base_BULAC_MS_ARA_417_0087_0
# ... Done base_BULAC_MS_ARA_609_00011_0
# ... Done base_BULAC_MS_ARA_609_00064_0
# ... Done base_BULAC_MS_ARA_609_00103_0
# ... Done base_BULAC_MS_ARA_417_0052_0
# ... Done base_BULAC_MS_ARA_417_0098_0
# ... Done base_BULAC_MS_ARA_609_00026_0
# ... Done base_BULAC_MS_ARA_417_0053_0
# ... Done base_BULAC_MS_ARA_1977_0012_0
# ... Done base_BULAC_MS_ARA_417_0006_0
# ... Done base_BULAC_MS_ARA_417_0032_0
# ... Done base_BULAC_MS_ARA_1977_0078_0
# ... Done base_BULAC_MS_ARA_609_00014_0
# ... Done base_BULAC_MS_ARA_609_00163_0
# ... Done base_BULAC_MS_ARA_609_00119_0
# ... Done base_BULAC_MS_ARA_1977_0041_0
# ... Done base_BULAC_MS_ARA_609_00097_0
# ... Done base_BULAC_MS_ARA_609_00167_0
# ... Done base_BULAC_MS_ARA_609_00191_1
# ... Done base_BULAC_MS_ARA_417_0034_0
# ... Done base_BULAC_MS_ARA_1977_0134_0
# ... Done base_BULAC_MS_ARA_609_00195_0
# ... Done base_BULAC_MS_ARA_1977_0176_0
# ... Done base_BULAC_MS_ARA_609_00109_0
# ... Done base_BULAC_MS_ARA_417_0019_0
# ... Done base_BULAC_MS_ARA_417_0012_0
# ... Done base_BULAC_MS_ARA_609_00137_0
# ....Doing base_BULAC_MS_ARA_417_0010_0
# .... 12
# No polygon pts in img _417_0010_0.png line number 1
# No polygon pts in img _417_0010_0.png line number 2
# No polygon pts in img _417_0010_0.png line number 3
# No polygon pts in img _417_0010_0.png line number 4
# No polygon pts in img _417_0010_0.png line number 5
# No polygon pts in img _417_0010_0.png line number 6
# No polygon pts in img _417_0010_0.png line number 7
# No polygon pts in img _417_0010_0.png line number 8
# No polygon pts in img _417_0010_0.png line number 9
# No polygon pts in img _417_0010_0.png line number 10
# No polygon pts in img _417_0010_0.png line number 11
# No polygon pts in img _417_0010_0.png line number 12
# Not added base_BULAC_MS_ARA_417_0010_0
# ... Done base_BULAC_MS_ARA_1977_0114_0
# ... Done base_BULAC_MS_ARA_609_00157_0
# ... Done base_BULAC_MS_ARA_609_00116_0
# ... Done base_BULAC_MS_ARA_417_0083_0
# ... Done base_BULAC_MS_ARA_417_0024_0
# ... Done base_BULAC_MS_ARA_1977_0080_0
# ... Done base_BULAC_MS_ARA_1977_0090_0
# ... Done base_BULAC_MS_ARA_1977_0019_0
# ... Done base_BULAC_MS_ARA_609_00125_0
# ... Done base_BULAC_MS_ARA_609_00202_0
# ... Done base_BULAC_MS_ARA_609_00016_0
# ... Done base_BULAC_MS_ARA_417_0035_0
# ... Done base_BULAC_MS_ARA_1977_0148_0
# ... Done base_BULAC_MS_ARA_609_00104_0
# Total files in set Valid: 35
# ... Done base_BULAC_MS_ARA_1977_0103_0
# ... Done base_BULAC_MS_ARA_417_0067_0
# ... Done base_BULAC_MS_ARA_1977_0147_0
# ... Done base_BULAC_MS_ARA_609_00017_0
# ... Done base_BULAC_MS_ARA_417_0071_0
# ... Done base_BULAC_MS_ARA_609_00048_0
# ... Done base_BULAC_MS_ARA_1977_0062_0
# ... Done base_BULAC_MS_ARA_1977_0192_0
# ... Done base_BULAC_MS_ARA_1977_0140_0
# ... Done base_BULAC_MS_ARA_417_0041_0
# ... Done base_BULAC_MS_ARA_417_0074_0
# ... Done base_BULAC_MS_ARA_1977_0158_0
# ... Done base_BULAC_MS_ARA_1977_0095_0
# ... Done base_BULAC_MS_ARA_417_0073_0
# ... Done base_BULAC_MS_ARA_1977_0054_0
# ... Done base_BULAC_MS_ARA_609_00087_0
# ... Done base_BULAC_MS_ARA_1977_0145_0
# ... Done base_BULAC_MS_ARA_609_00171_0
# ... Done base_BULAC_MS_ARA_1977_0016_0
# ... Done base_BULAC_MS_ARA_609_00170_0
# Total files in set Train: 110
# ... Done base_Add MS 7474_0044_0
# ... Done base_AHTD3A0611_Para3
# ... Done base_AHTD3A0612_Para2
# ... Done base_AHTD3A0613_Para2
# ... Done base_AHTD3A0613_Para3
# ... Done base_AHTD3A0614_Para2
# ... Done base_AHTD3A0614_Para3
# ... Done base_AHTD3A0615_Para2
# ... Done base_AHTD3A0615_Para3
# ... Done base_AHTD3A0617_Para2
# ... Done base_AHTD3A0617_Para3
# ... Done base_AHTD3A0619_Para2
# ... Done base_AHTD3A0619_Para3
# ... Done base_AHTD3A0621_Para2
# ... Done base_AHTD3A0621_Para3
# ... Done base_AHTD3A0622_Para2
# ... Done base_AHTD3A0622_Para3
# ... Done base_AHTD3A0624_Para2
# ... Done base_AHTD3A0624_Para3
# ... Done base_AHTD3A0625_Para2
# ... Done base_AHTD3A0625_Para3
# ... Done base_AHTD3A0626_Para2
# ... Done base_AHTD3A0626_Para3
# ... Done base_AHTD3A0628_Para2
# done 500
# ... Done base_AHTD3A0628_Para3
# ... Done base_AHTD3A0629_Para2
# ... Done base_AHTD3A0629_Para3
# ... Done base_AHTD3A0630_Para3
# ... Done base_AHTD3A0631_Para2
# ... Done base_AHTD3A0631_Para3
# ... Done base_AHTD3A0632_Para2
# ... Done base_AHTD3A0632_Para3
# ... Done base_AHTD3A0634_Para2
# ... Done base_AHTD3A0634_Para3
# ... Done base_AHTD3A0636_Para2
# ... Done base_AHTD3A0636_Para3
# ... Done base_AHTD3A0637_Para2
# ... Done base_AHTD3A0637_Para3
# ... Done base_AHTD3A0638_Para2
# ... Done base_AHTD3A0638_Para3
# ... Done base_AHTD3A0639_Para2
# ... Done base_AHTD3A0639_Para3
# ... Done base_AHTD3A0640_Para2
# ... Done base_AHTD3A0640_Para3
# ... Done base_AHTD3A0641_Para2
# ... Done base_AHTD3A0641_Para3
# ... Done base_AHTD3A0642_Para2
# ... Done base_AHTD3A0642_Para3
# ... Done base_AHTD3A0643_Para2
# ... Done base_AHTD3A0643_Para3
# ... Done base_AHTD3A0644_Para2
# ... Done base_AHTD3A0644_Para3
# ... Done base_AHTD3A0645_Para2
# ... Done base_AHTD3A0645_Para3
# ... Done base_AHTD3A0646_Para2
# ... Done base_AHTD3A0646_Para3
# ... Done base_AHTD3A0647_Para2
# ... Done base_AHTD3A0647_Para3
# ... Done base_AHTD3A0648_Para2
# ... Done base_AHTD3A0648_Para3
# ... Done base_AHTD3A0649_Para2
# ... Done base_AHTD3A0649_Para3
# ... Done base_AHTD3A0650_Para2
# ... Done base_AHTD3A0650_Para3
# ... Done base_AHTD3A0651_Para2
# ... Done base_AHTD3A0651_Para3
# ... Done base_AHTD3A0652_Para2
# ... Done base_AHTD3A0652_Para3
# ... Done base_AHTD3A0653_Para3
# ... Done base_AHTD3A0654_Para2
# ... Done base_AHTD3A0654_Para3
# ... Done base_AHTD3A0655_Para2
# ... Done base_AHTD3A0655_Para3
# ... Done base_AHTD3A0656_Para2
# ... Done base_AHTD3A0656_Para3
# ... Done base_AHTD3A0657_Para2
# ... Done base_AHTD3A0657_Para3
# ... Done base_AHTD3A0658_Para2
# ... Done base_AHTD3A0658_Para3
# ... Done base_AHTD3A0659_Para2
# ... Done base_AHTD3A0659_Para3
# ... Done base_AHTD3A0660_Para2
# ... Done base_AHTD3A0660_Para3
# ... Done base_AHTD3A0662_Para2
# ... Done base_AHTD3A0662_Para3
# ... Done base_AHTD3A0663_Para2
# ... Done base_AHTD3A0663_Para3
# ... Done base_AHTD3A0664_Para2
# ... Done base_AHTD3A0664_Para3
# ... Done base_AHTD3A0666_Para2
# ... Done base_AHTD3A0666_Para3
# ... Done base_AHTD3A0667_Para2
# ... Done base_AHTD3A0668_Para2
# ... Done base_AHTD3A0668_Para3
# ... Done base_AHTD3A0669_Para2
# ... Done base_AHTD3A0669_Para3
# ... Done base_AHTD3A0670_Para2
# ... Done base_AHTD3A0670_Para3
# ... Done base_AHTD3A0671_Para2
# ... Done base_AHTD3A0671_Para3
# ... Done base_AHTD3A0672_Para2
# ... Done base_AHTD3A0672_Para3
# ... Done base_AHTD3A0673_Para2
# ... Done base_AHTD3A0673_Para3
# ... Done base_AHTD3A0676_Para2
# ... Done base_AHTD3A0676_Para3
# ... Done base_AHTD3A0677_Para2
# ... Done base_AHTD3A0677_Para3
# ... Done base_AHTD3A0679_Para2
# ... Done base_AHTD3A0679_Para3
# ... Done base_AHTD3A0680_Para2
# ... Done base_AHTD3A0680_Para3
# ... Done base_AHTD3A0681_Para2
# ... Done base_AHTD3A0681_Para3
# ... Done base_AHTD3A0682_Para2
# ... Done base_AHTD3A0682_Para3
# ... Done base_AHTD3A0683_Para2
# ... Done base_AHTD3A0683_Para3
# ... Done base_AHTD3A0684_Para2
# ... Done base_AHTD3A0684_Para3
# ... Done base_AHTD3A0685_Para2
# ... Done base_AHTD3A0685_Para3
# ... Done base_AHTD3A0687_Para2
# ... Done base_AHTD3A0687_Para3
# done 600
# ... Done base_AHTD3A0688_Para2
# ... Done base_AHTD3A0688_Para3
# ... Done base_AHTD3A0690_Para2
# ... Done base_AHTD3A0690_Para3
# ... Done base_AHTD3A0692_Para2
# ... Done base_AHTD3A0693_Para2
# ... Done base_AHTD3A0693_Para3
# ... Done base_AHTD3A0694_Para2
# ... Done base_AHTD3A0694_Para3
# ... Done base_AHTD3A0695_Para2
# ... Done base_AHTD3A0695_Para3
# ... Done base_AHTD3A0696_Para2
# ... Done base_AHTD3A0696_Para3
# ... Done base_AHTD3A0697_Para2
# ... Done base_AHTD3A0697_Para3
# ... Done base_AHTD3A0698_Para2
# ... Done base_AHTD3A0698_Para3
# ... Done base_AHTD3A0699_Para2
# ... Done base_AHTD3A0699_Para3
# ... Done base_AHTD3A0700_Para2
# ... Done base_AHTD3A0700_Para3
# ... Done base_AHTD3A0702_Para2
# ... Done base_AHTD3A0702_Para3
# ... Done base_AHTD3A0703_Para2
# ... Done base_AHTD3A0703_Para3
# ... Done base_AHTD3A0704_Para2
# ... Done base_AHTD3A0705_Para2
# ... Done base_AHTD3A0705_Para3
# ... Done base_AHTD3A0706_Para2
# ... Done base_AHTD3A0706_Para3
# ... Done base_AHTD3A0707_Para2
# ... Done base_AHTD3A0707_Para3
# ... Done base_AHTD3A0708_Para2
# ... Done base_AHTD3A0708_Para3
# ... Done base_AHTD3A0709_Para2
# ... Done base_AHTD3A0709_Para3
# ... Done base_AHTD3A0710_Para3
# ... Done base_AHTD3A0711_Para2
# ... Done base_AHTD3A0711_Para3
# ... Done base_AHTD3A0712_Para2
# ... Done base_AHTD3A0712_Para3
# ... Done base_AHTD3A0713_Para2
# ... Done base_AHTD3A0713_Para3
# ... Done base_AHTD3A0715_Para2
# ... Done base_AHTD3A0715_Para3
# ... Done base_AHTD3A0716_Para2
# ... Done base_AHTD3A0716_Para3
# ... Done base_AHTD3A0718_Para2
# ... Done base_AHTD3A0718_Para3
# ... Done base_AHTD3A0719_Para2
# ... Done base_AHTD3A0719_Para3
# ... Done base_AHTD3A0720_Para2
# ... Done base_AHTD3A0720_Para3
# ... Done base_AHTD3A0721_Para2
# ... Done base_AHTD3A0721_Para3
# ... Done base_AHTD3A0722_Para2
# ... Done base_AHTD3A0722_Para3
# ... Done base_AHTD3A0723_Para2
# ... Done base_AHTD3A0723_Para3
# ... Done base_AHTD3A0724_Para2
# ... Done base_AHTD3A0724_Para3
# ... Done base_AHTD3A0725_Para2
# ... Done base_AHTD3A0725_Para3
# ... Done base_AHTD3A0727_Para2
# ... Done base_AHTD3A0727_Para3
# ... Done base_AHTD3A0728_Para2
# ... Done base_AHTD3A0728_Para3
# ... Done base_AHTD3A0729_Para2
# ... Done base_AHTD3A0729_Para3
# ... Done base_AHTD3A0730_Para2
# ... Done base_AHTD3A0730_Para3
# ... Done base_AHTD3A0732_Para2
# ... Done base_AHTD3A0732_Para3
# ... Done base_AHTD3A0733_Para2
# ... Done base_AHTD3A0733_Para3
# ... Done base_AHTD3A0734_Para2
# ... Done base_AHTD3A0734_Para3
# ... Done base_AHTD3A0735_Para2
# ... Done base_AHTD3A0735_Para3
# ... Done base_AHTD3A0736_Para2
# ... Done base_AHTD3A0736_Para3
# ... Done base_AHTD3A0737_Para2
# ... Done base_AHTD3A0737_Para3
# ... Done base_AHTD3A0739_Para2
# ... Done base_AHTD3A0739_Para3
# ... Done base_AHTD3A0741_Para2
# ... Done base_AHTD3A0741_Para3
# ... Done base_AHTD3A0742_Para2
# ... Done base_AHTD3A0742_Para3
# ... Done base_AHTD3A0744_Para2
# ... Done base_AHTD3A0744_Para3
# ... Done base_AHTD3A0746_Para2
# ... Done base_AHTD3A0746_Para3
# ... Done base_AHTD3A0747_Para2
# ... Done base_AHTD3A0747_Para3
# ... Done base_AHTD3A0748_Para2
# ... Done base_AHTD3A0748_Para3
# ... Done base_AHTD3A0749_Para2
# ... Done base_AHTD3A0749_Para3
# ... Done base_AHTD3A0750_Para2
# done 700
# ... Done base_AHTD3A0750_Para3
# ... Done base_AHTD3A0751_Para2
# ... Done base_AHTD3A0752_Para2
# ... Done base_AHTD3A0752_Para3
# ... Done base_AHTD3A0753_Para2
# ... Done base_AHTD3A0753_Para3
# ... Done base_AHTD3A0755_Para3
# ... Done base_AHTD3A0757_Para2
# ... Done base_AHTD3A0757_Para3
# ... Done base_AHTD3A0758_Para2
# ... Done base_AHTD3A0758_Para3
# ... Done base_AHTD3A0759_Para2
# ... Done base_AHTD3A0759_Para3
# ... Done base_AHTD3A0760_Para2
# ... Done base_AHTD3A0760_Para3
# ... Done base_AHTD3A0761_Para2
# ... Done base_AHTD3A0761_Para3
# ... Done base_AHTD3A0762_Para2
# ... Done base_AHTD3A0762_Para3
# ... Done base_AHTD3A0763_Para2
# ... Done base_AHTD3A0764_Para2
# ... Done base_AHTD3A0764_Para3
# ... Done base_AHTD3A0769_Para2
# ... Done base_AHTD3A0769_Para3
# ... Done base_AHTD3A0770_Para2
# ... Done base_AHTD3A0770_Para3
# ... Done base_AHTD3A0771_Para2
# ... Done base_AHTD3A0771_Para3
# ... Done base_AHTD3A0772_Para2
# ... Done base_AHTD3A0772_Para3
# ... Done base_AHTD3A0773_Para2
# ... Done base_AHTD3A0773_Para3
# ... Done base_AHTD3A0774_Para2
# ... Done base_AHTD3A0774_Para3
# ... Done base_AHTD3A0775_Para2
# ... Done base_AHTD3A0775_Para3
# ... Done base_AHTD3A0776_Para2
# ... Done base_AHTD3A0776_Para3
# ... Done base_AHTD3A0777_Para3
# ... Done base_AHTD3A0778_Para2
# ... Done base_AHTD3A0778_Para3
# ... Done base_AHTD3A0779_Para2
# ... Done base_AHTD3A0779_Para3
# ... Done base_AHTD3A0780_Para2
# ... Done base_AHTD3A0780_Para3
# ... Done base_AHTD3A0781_Para3
# ... Done base_AHTD3A0784_Para2
# ... Done base_AHTD3A0784_Para3
# ... Done base_AHTD3A0786_Para2
# ... Done base_AHTD3A0786_Para3
# ... Done base_AHTD3A0787_Para2
# ... Done base_AHTD3A0788_Para2
# ... Done base_AHTD3A0789_Para2
# ... Done base_AHTD3A0789_Para3
# ... Done base_AHTD3A0791_Para2
# ... Done base_AHTD3A0791_Para3
# ... Done base_AHTD3A0792_Para2
# ... Done base_AHTD3A0792_Para3
# ... Done base_AHTD3A0793_Para2
# ... Done base_AHTD3A0793_Para3
# ... Done base_AHTD3A0794_Para2
# ... Done base_AHTD3A0794_Para3
# ... Done base_AHTD3A0795_Para2
# ... Done base_AHTD3A0795_Para3
# ... Done base_AHTD3A0796_Para2
# ... Done base_AHTD3A0796_Para3
# ... Done base_AHTD3A0797_Para2
# ... Done base_AHTD3A0797_Para3
# ... Done base_AHTD3A0798_Para2
# ... Done base_AHTD3A0798_Para3
# ... Done base_AHTD3A0799_Para2
# ... Done base_AHTD3A0799_Para3
# ... Done base_AHTD3A0800_Para2
# ... Done base_AHTD3A0800_Para3
# ... Done base_AHTD3A0801_Para2
# ... Done base_AHTD3A0801_Para3
# ... Done base_AHTD3A0802_Para2
# ... Done base_AHTD3A0802_Para3
# ... Done base_AHTD3A0804_Para2
# ... Done base_AHTD3A0804_Para3
# ... Done base_AHTD3A0806_Para3
# ... Done base_AHTD3A0808_Para2
# ... Done base_AHTD3A0808_Para3
# ... Done base_AHTD3A0809_Para2
# ... Done base_AHTD3A0809_Para3
# ... Done base_AHTD3A0810_Para2
# ... Done base_AHTD3A0810_Para3
# ... Done base_AHTD3A0811_Para2
# ... Done base_AHTD3A0811_Para3
# ... Done base_AHTD3A0812_Para2
# ... Done base_AHTD3A0812_Para3
# ... Done base_AHTD3A0813_Para2
# ... Done base_AHTD3A0813_Para3
# ... Done base_AHTD3A0814_Para2
# ... Done base_AHTD3A0814_Para3
# ... Done base_AHTD3A0815_Para2
# ... Done base_AHTD3A0815_Para3
# ... Done base_AHTD3A0816_Para2
# ... Done base_AHTD3A0816_Para3
# ... Done base_AHTD3A0817_Para2
# done 800
# ... Done base_AHTD3A0817_Para3
# ... Done base_AHTD3A0820_Para2
# ... Done base_AHTD3A0820_Para3
# ... Done base_AHTD3A0821_Para2
# ... Done base_AHTD3A0821_Para3
# ... Done base_AHTD3A0822_Para2
# ... Done base_AHTD3A0822_Para3
# ... Done base_AHTD3A0823_Para2
# ... Done base_AHTD3A0823_Para3
# ... Done base_AHTD3A0825_Para2
# ... Done base_AHTD3A0825_Para3
# ... Done base_AHTD3A0826_Para2
# ... Done base_AHTD3A0826_Para3
# ... Done base_AHTD3A0827_Para3
# ... Done base_AHTD3A0829_Para2
# ... Done base_AHTD3A0829_Para3
# ... Done base_AHTD3A0830_Para2
# ... Done base_AHTD3A0831_Para2
# ... Done base_AHTD3A0831_Para3
# ... Done base_AHTD3A0833_Para2
# ... Done base_AHTD3A0833_Para3
# ... Done base_AHTD3A0834_Para2
# ... Done base_AHTD3A0835_Para2
# ... Done base_AHTD3A0835_Para3
# ... Done base_AHTD3A0836_Para2
# ... Done base_AHTD3A0836_Para3
# ... Done base_AHTD3A0837_Para2
# ... Done base_AHTD3A0837_Para3
# ... Done base_AHTD3A0839_Para2
# ... Done base_AHTD3A0840_Para2
# ... Done base_AHTD3A0840_Para3
# ... Done base_AHTD3A0841_Para2
# ... Done base_AHTD3A0841_Para3
# ... Done base_AHTD3A0842_Para2
# ... Done base_AHTD3A0842_Para3
# ... Done base_AHTD3A0843_Para2
# ... Done base_AHTD3A0843_Para3
# ... Done base_AHTD3A0844_Para2
# ... Done base_AHTD3A0844_Para3
# ... Done base_AHTD3A0845_Para3
# ... Done base_AHTD3A0847_Para2
# ... Done base_AHTD3A0847_Para3
# ... Done base_AHTD3A0849_Para2
# ... Done base_AHTD3A0849_Para3
# ... Done base_AHTD3A0851_Para2
# ... Done base_AHTD3A0851_Para3
# ... Done base_AHTD3A0852_Para2
# ... Done base_AHTD3A0852_Para3
# ... Done base_AHTD3A0853_Para3
# ... Done base_AHTD3A0854_Para2
# ... Done base_AHTD3A0854_Para3
# ... Done base_AHTD3A0855_Para2
# ... Done base_AHTD3A0855_Para3
# ... Done base_AHTD3A0856_Para2
# ... Done base_AHTD3A0856_Para3
# ... Done base_AHTD3A0857_Para2
# ... Done base_AHTD3A0858_Para2
# ... Done base_AHTD3A0859_Para3
# ... Done base_AHTD3A0860_Para2
# ... Done base_AHTD3A0860_Para3
# ... Done base_AHTD3A0861_Para2
# ... Done base_AHTD3A0861_Para3
# ... Done base_AHTD3A0862_Para2
# ... Done base_AHTD3A0862_Para3
# ... Done base_AHTD3A0864_Para2
# ... Done base_AHTD3A0864_Para3
# ... Done base_AHTD3A0866_Para2
# ... Done base_AHTD3A0866_Para3
# ... Done base_AHTD3A0867_Para2
# ... Done base_AHTD3A0867_Para3
# ... Done base_AHTD3A0869_Para2
# ... Done base_AHTD3A0869_Para3
# ... Done base_AHTD3A0870_Para2
# ... Done base_AHTD3A0870_Para3
# ... Done base_AHTD3A0871_Para2
# ... Done base_AHTD3A0871_Para3
# ... Done base_AHTD3A0872_Para2
# ... Done base_AHTD3A0872_Para3
# ... Done base_AHTD3A0873_Para2
# ... Done base_AHTD3A0873_Para3
# ... Done base_AHTD3A0875_Para2
# ... Done base_AHTD3A0875_Para3
# ... Done base_AHTD3A0876_Para2
# ... Done base_AHTD3A0876_Para3
# ... Done base_AHTD3A0877_Para2
# ... Done base_AHTD3A0877_Para3
# ... Done base_AHTD3A0878_Para2
# ... Done base_AHTD3A0880_Para2
# ... Done base_AHTD3A0880_Para3
# ... Done base_AHTD3A0881_Para2
# ... Done base_AHTD3A0881_Para3
# ... Done base_AHTD3A0883_Para2
# ... Done base_AHTD3A0883_Para3
# ... Done base_AHTD3A0884_Para2
# ... Done base_AHTD3A0885_Para2
# ... Done base_AHTD3A0885_Para3
# ... Done base_AHTD3A0886_Para2
# ... Done base_AHTD3A0886_Para3
# ... Done base_AHTD3A0887_Para2
# ... Done base_AHTD3A0887_Para3
# done 900
# ... Done base_AHTD3A0888_Para2
# ... Done base_AHTD3A0889_Para2
# ... Done base_AHTD3A0889_Para3
# ... Done base_AHTD3A0890_Para2
# ... Done base_AHTD3A0890_Para3
# ... Done base_AHTD3A0892_Para2
# ... Done base_AHTD3A0892_Para3
# ... Done base_AHTD3A0893_Para2
# ... Done base_AHTD3A0893_Para3
# ... Done base_AHTD3A0894_Para2
# ... Done base_AHTD3A0894_Para3
# ... Done base_AHTD3A0895_Para2
# ... Done base_AHTD3A0895_Para3
# ... Done base_AHTD3A0896_Para2
# ... Done base_AHTD3A0896_Para3
# ... Done base_AHTD3A0897_Para2
# ... Done base_AHTD3A0897_Para3
# ... Done base_AHTD3A0898_Para2
# ... Done base_AHTD3A0898_Para3
# ... Done base_AHTD3A0899_Para3
# ... Done base_AHTD3A0900_Para2
# ... Done base_AHTD3A0900_Para3
# ... Done base_AHTD3A0901_Para2
# ... Done base_AHTD3A0901_Para3
# ... Done base_AHTD3A0903_Para2
# ... Done base_AHTD3A0903_Para3
# ... Done base_AHTD3A0904_Para2
# ... Done base_AHTD3A0904_Para3
# ... Done base_AHTD3A0905_Para2
# ... Done base_AHTD3A0905_Para3
# ... Done base_AHTD3A0906_Para2
# ... Done base_AHTD3A0906_Para3
# ... Done base_AHTD3A0908_Para2
# ... Done base_AHTD3A0908_Para3
# ... Done base_AHTD3A0909_Para2
# ... Done base_AHTD3A0909_Para3
# ... Done base_AHTD3A0910_Para2
# ... Done base_AHTD3A0910_Para3
# ... Done base_AHTD3A0912_Para2
# ... Done base_AHTD3A0912_Para3
# ... Done base_AHTD3A0913_Para3
# ... Done base_AHTD3A0916_Para2
# ... Done base_AHTD3A0917_Para2
# ... Done base_AHTD3A0917_Para3
# ... Done base_AHTD3A0919_Para2
# ... Done base_AHTD3A0919_Para3
# ... Done base_AHTD3A0920_Para2
# ... Done base_AHTD3A0920_Para3
# ... Done base_AHTD3A0923_Para2
# ... Done base_AHTD3A0923_Para3
# ... Done base_AHTD3A0924_Para2
# ... Done base_AHTD3A0924_Para3
# ... Done base_AHTD3A0925_Para2
# ... Done base_AHTD3A0925_Para3
# ... Done base_AHTD3A0926_Para2
# ... Done base_AHTD3A0926_Para3
# ... Done base_AHTD3A0927_Para2
# ... Done base_AHTD3A0927_Para3
# ... Done base_AHTD3A0928_Para2
# ... Done base_AHTD3A0928_Para3
# ... Done base_AHTD3A0930_Para2
# ... Done base_AHTD3A0930_Para3
# ... Done base_AHTD3A0931_Para2
# ... Done base_AHTD3A0931_Para3
# ... Done base_AHTD3A0933_Para2
# ... Done base_AHTD3A0933_Para3
# ... Done base_AHTD3A0934_Para2
# ... Done base_AHTD3A0934_Para3
# ... Done base_AHTD3A0935_Para2
# ... Done base_AHTD3A0935_Para3
# ... Done base_AHTD3A0936_Para2
# ... Done base_AHTD3A0936_Para3
# ... Done base_AHTD3A0937_Para2
# ... Done base_AHTD3A0937_Para3
# ... Done base_AHTD3A0939_Para2
# ... Done base_AHTD3A0940_Para2
# ... Done base_AHTD3A0940_Para3
# ... Done base_AHTD3A0941_Para2
# ... Done base_AHTD3A0941_Para3
# ... Done base_AHTD3A0943_Para2
# ... Done base_AHTD3A0943_Para3
# ... Done base_AHTD3A0945_Para2
# ... Done base_AHTD3A0945_Para3
# ... Done base_AHTD3A0946_Para2
# ... Done base_AHTD3A0946_Para3
# ... Done base_AHTD3A0947_Para2
# ... Done base_AHTD3A0947_Para3
# ... Done base_AHTD3A0948_Para3
# ... Done base_AHTD3A0949_Para2
# ... Done base_AHTD3A0949_Para3
# ... Done base_AHTD3A0950_Para2
# ... Done base_AHTD3A0950_Para3
# ... Done base_AHTD3A0951_Para2
# ... Done base_AHTD3A0951_Para3
# ... Done base_AHTD3A0952_Para2
# ... Done base_AHTD3A0952_Para3
# ... Done base_AHTD3A0953_Para2
# ... Done base_AHTD3A0953_Para3
# ... Done base_AHTD3A0954_Para3
# ... Done base_AHTD3A0955_Para2
# done 1000
# ... Done base_AHTD3A0955_Para3
# ... Done base_AHTD3A0956_Para2
# ... Done base_AHTD3A0956_Para3
# ... Done base_AHTD3A0957_Para2
# ... Done base_AHTD3A0957_Para3
# ... Done base_AHTD3A0958_Para2
# ... Done base_AHTD3A0958_Para3
# ... Done base_AHTD3A0959_Para2
# ... Done base_AHTD3A0959_Para3
# ... Done base_AHTD3A0960_Para2
# ... Done base_AHTD3A0960_Para3
# ... Done base_AHTD3A0962_Para2
# ... Done base_AHTD3A0962_Para3
# ... Done base_AHTD3A0963_Para2
# ... Done base_AHTD3A0963_Para3
# ... Done base_AHTD3A0965_Para2
# ... Done base_AHTD3A0965_Para3
# ... Done base_AHTD3A0966_Para2
# ... Done base_AHTD3A0966_Para3
# ... Done base_AHTD3A0967_Para2
# ... Done base_AHTD3A0967_Para3
# ... Done base_AHTD3A0968_Para2
# ... Done base_AHTD3A0968_Para3
# ... Done base_AHTD3A0969_Para3
# ... Done base_AHTD3A0970_Para2
# ... Done base_AHTD3A0970_Para3
# ... Done base_AHTD3A0971_Para2
# ... Done base_AHTD3A0971_Para3
# ... Done base_AHTD3A0973_Para2
# ... Done base_AHTD3A0973_Para3
# ... Done base_AHTD3A0974_Para2
# ... Done base_AHTD3A0974_Para3
# ... Done base_AHTD3A0976_Para2
# ... Done base_AHTD3A0976_Para3
# ... Done base_AHTD3A0977_Para2
# ... Done base_AHTD3A0977_Para3
# ... Done base_AHTD3A0979_Para2
# ... Done base_AHTD3A0979_Para3
# ... Done base_AHTD3A0980_Para2
# ... Done base_AHTD3A0980_Para3
# ... Done base_AHTD3A0982_Para2
# ... Done base_AHTD3A0982_Para3
# ... Done base_AHTD3A0983_Para2
# ... Done base_AHTD3A0983_Para3
# ... Done base_AHTD3A0985_Para2
# ... Done base_AHTD3A0985_Para3
# ... Done base_AHTD3A0986_Para2
# ... Done base_AHTD3A0986_Para3
# ... Done base_AHTD3A0987_Para2
# ... Done base_AHTD3A0987_Para3
# ... Done base_AHTD3A0988_Para2
# ... Done base_AHTD3A0989_Para2
# ... Done base_AHTD3A0989_Para3
# ... Done base_AHTD3A0990_Para3
# ... Done base_AHTD3A0991_Para2
# ... Done base_AHTD3A0991_Para3
# ... Done base_AHTD3A0994_Para3
# ... Done base_AHTD3A0995_Para2
# ... Done base_AHTD3A0995_Para3
# ... Done base_AHTD3A0997_Para2
# ... Done base_AHTD3A0997_Para3
# ... Done base_AHTD3A0998_Para2
# ... Done base_AHTD3A0998_Para3
# ... Done base_AHTD3A1000_Para2
# ... Done base_AHTD3A1000_Para3
# ... Done base_AHTD3A1001_Para2
# ... Done base_AHTD3A1001_Para3
# ... Done base_AHTD3A1003_Para2
# ... Done base_AHTD3A1003_Para3
# ... Done base_AHTD3A1005_Para2
# ... Done base_AHTD3A1005_Para3
# ... Done base_AHTD3A1006_Para2
# ... Done base_AHTD3A1006_Para3
# ... Done base_AHTD3A1007_Para2
# ... Done base_AHTD3A1007_Para3
# ... Done base_AHTD3A1008_Para2
# ... Done base_AHTD3A1009_Para2
# ... Done base_AHTD3A1009_Para3
# ... Done base_AHTD3A1010_Para2
# ... Done base_AHTD3A1010_Para3
# ... Done base_AHTD3A1011_Para2
# ... Done base_AHTD3A1011_Para3
# ... Done base_AHTD3A1012_Para2
# ... Done base_AHTD3A1012_Para3
# ... Done base_AHTD3A1014_Para2
# ... Done base_AHTD3A1014_Para3
# ... Done base_AHTD3A1018_Para2
# ... Done base_AHTD3A1018_Para3
# ... Done base_AHTD3A1019_Para2
# ... Done base_AHTD3A1019_Para3
# ... Done base_AHTD3A1020_Para2
# ... Done base_AHTD3A1020_Para3
# ... Done base_AHTD3A1022_Para2
# ... Done base_AHTD3A1106_Para3
# ... Done base_AHTD3A1107_Para2
# ... Done base_AHTD3A1107_Para3
# ... Done base_AHTD3A1108_Para2
# ... Done base_AHTD3A1108_Para3
# ... Done base_AHTD3A1109_Para2
# ... Done base_AHTD3A1109_Para3
# ... Done base_AHTD3A1110_Para2
# ...
# ... Done base_AHTD3A1160_Para2
# ... Done base_AHTD3A1160_Para3
# ... Done base_AHTD3A1161_Para2
# ... Done base_AHTD3A1161_Para3
# ... Done base_AHTD3A1165_Para2
# ... Done base_AHTD3A1165_Para3
# ... Done base_AHTD3A1166_Para2
# ... Done base_AHTD3A1166_Para3
# ... Done base_AHTD3A1167_Para2
# ... Done base_AHTD3A1167_Para3
# ... Done base_AHTD3A1168_Para2
# ... Done base_AHTD3A1168_Para3
# ... Done base_AHTD3A1169_Para2
# ... Done base_AHTD3A1169_Para3
# Total files in set Validate: 251
# ... Done base_AHTD3A0001_Para2
# ... Done base_AHTD3A0001_Para3
# ... Done base_AHTD3A0005_Para2
# ... Done base_AHTD3A0005_Para3
# ... Done base_AHTD3A0047_Para2
# ... Done base_AHTD3A0047_Para3
# ... Done base_AHTD3A0072_Para2
# ... Done base_AHTD3A0072_Para3
# ... Done base_AHTD3A0077_Para3
# ... Done base_AHTD3A0078_Para2
# ... Done base_AHTD3A0078_Para3
# ... Done base_AHTD3A0080_Para2
# ... Done base_AHTD3A0080_Para3
# ... Done base_AHTD3A0081_Para2
# ... Done base_AHTD3A0081_Para3
# ... Done base_AHTD3A0084_Para2
# ... Done base_AHTD3A0084_Para3
# ... Done base_AHTD3A0086_Para2
# ... Done base_AHTD3A0086_Para3
# ... Done base_AHTD3A0089_Para2
# ... Done base_AHTD3A0089_Para3
# ... Done base_AHTD3A0091_Para2
# ... Done base_AHTD3A0091_Para3
# ... Done base_AHTD3A0092_Para2
# ... Done base_AHTD3A0094_Para2
# ... Done base_AHTD3A0094_Para3
# ... Done base_AHTD3A0096_Para2
# ... Done base_AHTD3A0096_Para3
# ... Done base_AHTD3A0102_Para2
# ... Done base_AHTD3A0105_Para2
# ... Done base_AHTD3A0105_Para3
# ... Done base_AHTD3A0127_Para2
# ... Done base_AHTD3A0130_Para2
# ... Done base_AHTD3A0130_Para3
# ... Done base_AHTD3A0133_Para2
# ... Done base_AHTD3A0133_Para3
# ... Done base_AHTD3A0139_Para2
# ... Done base_AHTD3A0139_Para3
# ... Done base_AHTD3A0143_Para2
# ... Done base_AHTD3A0145_Para2
# ... Done base_AHTD3A0145_Para3
# ... Done base_AHTD3A0163_Para2
# ... Done base_AHTD3A0164_Para2
# ... Done base_AHTD3A0164_Para3
# ... Done base_AHTD3A0165_Para2
# ... Done base_AHTD3A0165_Para3
# ... Done base_AHTD3A0166_Para2
# ... Done base_AHTD3A0166_Para3
# ... Done base_AHTD3A0170_Para2
# ... Done base_AHTD3A0170_Para3
# ... Done base_AHTD3A0176_Para2
# ... Done base_AHTD3A0177_Para2
# ... Done base_AHTD3A0177_Para3
# ... Done base_AHTD3A0178_Para2
# ... Done base_AHTD3A0178_Para3
# ... Done base_AHTD3A0185_Para2
# ... Done base_AHTD3A0185_Para3
# ... Done base_AHTD3A0186_Para2
# ... Done base_AHTD3A0186_Para3
# ... Done base_AHTD3A0187_Para2
# ... Done base_AHTD3A0188_Para2
# ... Done base_AHTD3A0188_Para3
# ... Done base_AHTD3A0190_Para2
# ... Done base_AHTD3A0190_Para3
# ... Done base_AHTD3A0191_Para2
# ... Done base_AHTD3A0192_Para2
# ... Done base_AHTD3A0192_Para3
# ... Done base_AHTD3A0193_Para2
# ... Done base_AHTD3A0193_Para3
# ... Done base_AHTD3A0194_Para2
# ... Done base_AHTD3A0194_Para3
# ... Done base_AHTD3A0195_Para2
# ... Done base_AHTD3A0195_Para3
# ... Done base_AHTD3A0197_Para2
# ... Done base_AHTD3A0197_Para3
# ... Done base_AHTD3A0199_Para2
# ... Done base_AHTD3A0199_Para3
# ... Done base_AHTD3A0204_Para2
# ... Done base_AHTD3A0204_Para3
# ... Done base_AHTD3A0205_Para2
# ... Done base_AHTD3A0205_Para3
# ... Done base_AHTD3A0206_Para2
# ... Done base_AHTD3A0206_Para3
# ... Done base_AHTD3A0207_Para2
# ... Done base_AHTD3A0207_Para3
# ... Done base_AHTD3A0208_Para3
# ... Done base_AHTD3A0209_Para2
# ... Done base_AHTD3A0211_Para2
# ... Done base_AHTD3A0211_Para3
# ... Done base_AHTD3A0213_Para3
# ... Done base_AHTD3A0216_Para2
# ... Done base_AHTD3A0216_Para3
# ... Done base_AHTD3A0219_Para2
# ... Done base_AHTD3A0219_Para3
# ... Done base_AHTD3A0224_Para2
# ... Done base_AHTD3A0224_Para3
# ... Done base_AHTD3A0225_Para2
# ... Done base_AHTD3A0225_Para3
# ... Done base_AHTD3A0228_Para2
# ... Done base_AHTD3A0228_Para3
# done 100
# ... Done base_AHTD3A0232_Para2
# ... Done base_AHTD3A0232_Para3
# ... Done base_AHTD3A0238_Para2
# ... Done base_AHTD3A0238_Para3
# ... Done base_AHTD3A0241_Para2
# ... Done base_AHTD3A0241_Para3
# ... Done base_AHTD3A0242_Para2
# ... Done base_AHTD3A0242_Para3
# ... Done base_AHTD3A0243_Para2
# ... Done base_AHTD3A0243_Para3
# ... Done base_AHTD3A0244_Para3
# ... Done base_AHTD3A0247_Para2
# ... Done base_AHTD3A0247_Para3
# ... Done base_AHTD3A0248_Para2
# ... Done base_AHTD3A0248_Para3
# ... Done base_AHTD3A0252_Para2
# ... Done base_AHTD3A0252_Para3
# ... Done base_AHTD3A0253_Para2
# ... Done base_AHTD3A0253_Para3
# ... Done base_AHTD3A0258_Para2
# ... Done base_AHTD3A0258_Para3
# ... Done base_AHTD3A0261_Para2
# ... Done base_AHTD3A0261_Para3
# ... Done base_AHTD3A0262_Para2
# ... Done base_AHTD3A0262_Para3
# ... Done base_AHTD3A0264_Para2
# ... Done base_AHTD3A0264_Para3
# ... Done base_AHTD3A0267_Para2
# ... Done base_AHTD3A0267_Para3
# ... Done base_AHTD3A0268_Para2
# ... Done base_AHTD3A0268_Para3
# ... Done base_AHTD3A0269_Para2
# ... Done base_AHTD3A0269_Para3
# ... Done base_AHTD3A0270_Para2
# ... Done base_AHTD3A0272_Para2
# ... Done base_AHTD3A0272_Para3
# ... Done base_AHTD3A0275_Para2
# ... Done base_AHTD3A0275_Para3
# ... Done base_AHTD3A0276_Para2
# ... Done base_AHTD3A0276_Para3
# ... Done base_AHTD3A0300_Para2
# ... Done base_AHTD3A0300_Para3
# ... Done base_AHTD3A0301_Para2
# ... Done base_AHTD3A0301_Para3
# ... Done base_AHTD3A0302_Para2
# ... Done base_AHTD3A0302_Para3
# ... Done base_AHTD3A0313_Para2
# ... Done base_AHTD3A0313_Para3
# ... Done base_AHTD3A0321_Para2
# ... Done base_AHTD3A0321_Para3
# ... Done base_AHTD3A0324_Para2
# ... Done base_AHTD3A0324_Para3
# ... Done base_AHTD3A0335_Para2
# ... Done base_AHTD3A0335_Para3
# ... Done base_AHTD3A0340_Para2
# ... Done base_AHTD3A0340_Para3
# ... Done base_AHTD3A0351_Para2
# ... Done base_AHTD3A0351_Para3
# ... Done base_AHTD3A0353_Para2
# ... Done base_AHTD3A0353_Para3
# ... Done base_AHTD3A0356_Para2
# ... Done base_AHTD3A0356_Para3
# ... Done base_AHTD3A0357_Para2
# ... Done base_AHTD3A0357_Para3
# ... Done base_AHTD3A0358_Para2
# ... Done base_AHTD3A0358_Para3
# ... Done base_AHTD3A0365_Para2
# ... Done base_AHTD3A0365_Para3
# ... Done base_AHTD3A0366_Para3
# ... Done base_AHTD3A0367_Para2
# ... Done base_AHTD3A0367_Para3
# ... Done base_AHTD3A0369_Para2
# ... Done base_AHTD3A0369_Para3
# ... Done base_AHTD3A0370_Para3
# ... Done base_AHTD3A0380_Para2
# ... Done base_AHTD3A0380_Para3
# ... Done base_AHTD3A0388_Para2
# ... Done base_AHTD3A0388_Para3
# ... Done base_AHTD3A0392_Para3
# ... Done base_AHTD3A0395_Para2
# ... Done base_AHTD3A0396_Para2
# ... Done base_AHTD3A0403_Para2
# ... Done base_AHTD3A0403_Para3
# ... Done base_AHTD3A0404_Para2
# ... Done base_AHTD3A0404_Para3
# ... Done base_AHTD3A0405_Para2
# ... Done base_AHTD3A0405_Para3
# ... Done base_AHTD3A0409_Para2
# ... Done base_AHTD3A0409_Para3
# ... Done base_AHTD3A0413_Para2
# ... Done base_AHTD3A0413_Para3
# ... Done base_AHTD3A0429_Para2
# ... Done base_AHTD3A0429_Para3
# ... Done base_AHTD3A0443_Para3
# ... Done base_AHTD3A0470_Para2
# ... Done base_AHTD3A0470_Para3
# ... Done base_AHTD3A0477_Para2
# ... Done base_AHTD3A0477_Para3
# ... Done base_AHTD3A0503_Para2
# ... Done base_AHTD3A0503_Para3
# done 200
# ... Done base_AHTD3A0504_Para2
# ... Done base_AHTD3A0504_Para3
# ... Done base_AHTD3A0505_Para2
# ... Done base_AHTD3A0505_Para3
# ... Done base_AHTD3A0506_Para2
# ... Done base_AHTD3A0508_Para2
# ... Done base_AHTD3A0510_Para2
# ... Done base_AHTD3A0510_Para3
msaeed3/mehreen/datasets/RASAM/regions_sfr/Valid/base_BULAC_MS_ARA_417_0073_0/base_BULAC_MS_ARA_417_0073_0.json', '/home/msaeed3/mehreen/datasets/RASAM/regions/BULAC_MS_ARA_417_0073_0.png'], ['/home/msaeed3/mehreen/datasets/RASAM/regions_sfr/Valid/base_BULAC_MS_ARA_1977_0054_0/base_BULAC_MS_ARA_1977_0054_0.json', '/home/msaeed3/mehreen/datasets/RASAM/regions/BULAC_MS_ARA_1977_0054_0.png'], ['/home/msaeed3/mehreen/datasets/RASAM/regions_sfr/Valid/base_BULAC_MS_ARA_609_00087_0/base_BULAC_MS_ARA_609_00087_0.json', '/home/msaeed3/mehreen/datasets/RASAM/regions/BULAC_MS_ARA_609_00087_0.png'], ['/home/msaeed3/mehreen/datasets/RASAM/regions_sfr/Valid/base_BULAC_MS_ARA_1977_0145_0/base_BULAC_MS_ARA_1977_0145_0.json', '/home/msaeed3/mehreen/datasets/RASAM/regions/BULAC_MS_ARA_1977_0145_0.png'], ['/home/msaeed3/mehreen/datasets/RASAM/regions_sfr/Valid/base_BULAC_MS_ARA_609_00171_0/base_BULAC_MS_ARA_609_00171_0.json', '/home/msaeed3/mehreen/datasets/RASAM/regions/BULAC_MS_ARA_609_00171_0.png'], ['/home/msaeed3/mehreen/datasets/RASAM/regions_sfr/Valid/base_BULAC_MS_ARA_1977_0016_0/base_BULAC_MS_ARA_1977_0016_0.json', '/home/msaeed3/mehreen/datasets/RASAM/regions/BULAC_MS_ARA_1977_0016_0.png'], ['/home/msaeed3/mehreen/datasets/RASAM/regions_sfr/Valid/base_BULAC_MS_ARA_609_00170_0/base_BULAC_MS_ARA_609_00170_0.json', '/home/msaeed3/mehreen/datasets/RASAM/ ...
# all files done

# %% [markdown]
# # Uncomment this cell to check for a single file
#
# out_path = '/home/msaeed3/mehreen/datasets/MoiseK/'
#
# check_file = 'AR69_004.jpg'
# set_name = 'Valid'
#
# df = pd.read_csv(os.path.join(out_path, set_name + '.csv'))
# df.baseline = convert_str_to_int_tuples(df.baseline)
# #df.baseline = rotate_baseline_list(df.baseline)
# df.polygon_pts = convert_str_to_int_tuples(df.polygon_pts)
# #df.polygon_pts = rotate_poly_list(df.polygon_pts)
#
# files = df.image_file
#
# all_ground_truth = []
# for img_path in set(files):
#
#     if check_file in img_path:
#         print('***')
#         para_df = df[df.image_file == img_path]
#         para_df = para_df.copy()
#         para_df = para_df.reset_index(drop=True)
#         valid_region = any(s in para_df['region_type'][0] for s in ['paragraph','text'])
#         if not valid_region:
#             print('NOT DONE')
#         json_path = handle_single_para(para_df, out_path+set_name)
#         print(json_path)

# %%
para_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 para_df
#
# NameError: name 'para_df' is not defined

# %%
# This is for priinting the json file in readable format

json_file = '/home/msaeed3/mehreen/datasets/arabic_all/Train.json'
with open(json_file, 'r') as fin:
    json_obj = json.load(fin)

out_file = '/home/msaeed3/mehreen/datasets/arabic_all/Train_readable.json'
with open(out_file, 'w') as fout:
    json.dump(json_obj, fout, indent=2)
